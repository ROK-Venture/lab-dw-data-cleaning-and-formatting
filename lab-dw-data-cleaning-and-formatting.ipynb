# %% [markdown]
# # Lab | Data Cleaning and Formatting

# %% [markdown]
# In this lab, we will be working with the customer data from an insurance company, which can be found in the CSV file located at the following link: https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv

# %% [markdown]
# # Challenge 1: Data Cleaning and Formatting

# %% [markdown]
# ## Exercise 1: Cleaning Column Names

# %% [markdown]
# To ensure consistency and ease of use, standardize the column names of the dataframe. Start by taking a first look at the dataframe and identifying any column names that need to be modified. Use appropriate naming conventions and make sure that column names are descriptive and informative.
#
# *Hint*:
# - *Column names should be in lower case*
# - *White spaces in column names should be replaced by `_`*
# - *`st` could be replaced for `state`*

# %%
# Your code here
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'

df_insurance = pd.read_csv(url)

df_insurance
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df_insurance.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
df_insurance.columns = [col.lower() for col in df_insurance.columns]
df_insurance.head()
# Out:
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
df_insurance.rename(columns = {"customer lifetime value": "customer_lifetime_value", 
                                "monthly premium auto": "monthly_premium_auto", 
                                "number of open complaints": "number_of_open_complaints",	
                                "policy type": "policy_type",	
                                "vehicle class": "vehicle_class", 
                                "total claim amount": "total_claim_amount"}, inplace = True)

df_insurance.head()
# Out:
#   customer          st gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
df_insurance.rename(columns = {"st": "state"}, inplace = True)
df_insurance.head()
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
#alternative
#df_insurance.columns = ["customer", "state", "gender", "education", "customer_lifetime_va", "income", 
#                       "monthly_premium_auto", "number_of_open_complaints", "policy_type", "vehicle_class", "total_claim_amount"]

# %% [markdown]
# ## Exercise 2: Cleaning invalid Values

# %% [markdown]
# The dataset contains columns with inconsistent and incorrect values that could affect the accuracy of our analysis. Therefore, we need to clean these columns to ensure that they only contain valid data.
#
# Note that this exercise will focus only on cleaning inconsistent values and will not involve handling null values (NaN or None).
#
# *Hint*:
# - *Gender column contains various inconsistent values such as "F", "M", "Femal", "Male", "female", which need to be standardized, for example, to "M" and "F".*
# - *State abbreviations be can replaced with its full name, for example "AZ": "Arizona", "Cali": "California", "WA": "Washington"*
# - *In education, "Bachelors" could be replaced by "Bachelor"*
# - *In Customer Lifetime Value, delete the `%` character*
# - *In vehicle class, "Sports Car", "Luxury SUV" and "Luxury Car" could be replaced by "Luxury"*

# %%
df_insurance
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df_insurance.nunique()
# Out:
# customer                     1071
# state                           8
# gender                          5
# education                       6
# customer_lifetime_value      1027
# income                        774
# monthly_premium_auto          132
# number_of_open_complaints       6
# policy_type                     3
# vehicle_class                   6
# total_claim_amount            761
# dtype: int64

# %%
df_insurance["gender"].value_counts()
# Out:
# gender
# F         457
# M         413
# Male       39
# female     28
# Femal      17
# Name: count, dtype: int64

# %%
gender_map = {"M": "M", "F": "F", "Male": "M", "female": "F", "Femal": "F"}
df_insurance["gender"] = df_insurance["gender"].map(gender_map)

df_insurance["gender"].value_counts()
# Out:
# gender
# F    502
# M    452
# Name: count, dtype: int64

# %%
df_insurance["state"].value_counts()
# Out:
# state
# Oregon        320
# California    211
# Arizona       186
# Cali          120
# Nevada         98
# Washington     81
# WA             30
# AZ             25
# Name: count, dtype: int64

# %%
state_map = {"Oregon": "Oregon", "California": "Cali", "Arizona": "AZ", "Nevada": "Nevada", "Washington": "WA"}
df_insurance["state"] = df_insurance["state"].map(state_map)

df_insurance["state"].value_counts()
# Out:
# state
# Oregon    320
# Cali      211
# AZ        186
# Nevada     98
# WA         81
# Name: count, dtype: int64

# %%
df_insurance["education"].value_counts()
# Out:
# education
# Bachelor                324
# College                 313
# High School or Below    296
# Master                   94
# Doctor                   37
# Bachelors                 7
# Name: count, dtype: int64

# %%
education_map = {"Bachelor": "Bachelor", "College": "College", "High School or Below": "High School or Below", "Master": "Master","Doctor": "Doctor", "Bachelors": "Bachelor"}
df_insurance["education"] = df_insurance["education"].map(education_map)

df_insurance["education"].value_counts()
# Out:
# education
# Bachelor                331
# College                 313
# High School or Below    296
# Master                   94
# Doctor                   37
# Name: count, dtype: int64

# %%
df_insurance.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
df_insurance["customer_lifetime_value"].value_counts()
# Out:
# customer_lifetime_value
# 445811.34%     4
# 251459.20%     4
# 272535.64%     3
# 578018.22%     3
# 684615.03%     3
#               ..
# 245357.08%     1
# 507566.27%     1
# 321497.94%     1
# 1227534.31%    1
# 899704.02%     1
# Name: count, Length: 1027, dtype: int64

# %%
df_insurance['customer_lifetime_value'] = df_insurance['customer_lifetime_value'].str.replace('%', '')

df_insurance["customer_lifetime_value"].value_counts()
# Out:
# customer_lifetime_value
# 445811.34     4
# 251459.20     4
# 272535.64     3
# 578018.22     3
# 684615.03     3
#              ..
# 245357.08     1
# 507566.27     1
# 321497.94     1
# 1227534.31    1
# 899704.02     1
# Name: count, Length: 1027, dtype: int64

# %%
df_insurance.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
df_insurance["vehicle_class"].value_counts()
# Out:
# vehicle_class
# Four-Door Car    576
# Two-Door Car     205
# SUV              199
# Sports Car        57
# Luxury SUV        20
# Luxury Car        14
# Name: count, dtype: int64

# %%
vehicle_map = {"Four-Door Car": "Four-Door Car", "Two-Door Car": "Two-Door Car", "SUV": "SUV", "Sports Car": "Luxury","Luxury SUV": "Luxury", "Luxury Car": "Luxury"}
df_insurance["vehicle_class"] = df_insurance["vehicle_class"].map(vehicle_map)

df_insurance["vehicle_class"].value_counts()
# Out:
# vehicle_class
# Four-Door Car    576
# Two-Door Car     205
# SUV              199
# Luxury            91
# Name: count, dtype: int64

# %% [markdown]
# ## Exercise 3: Formatting data types

# %% [markdown]
# The data types of many columns in the dataset appear to be incorrect. This could impact the accuracy of our analysis. To ensure accurate analysis, we need to correct the data types of these columns. Please update the data types of the columns as appropriate.

# %% [markdown]
# It is important to note that this exercise does not involve handling null values (NaN or None).

# %% [markdown]
# *Hint*:
# - *Customer lifetime value should be numeric*
# - *Number of open complaints has an incorrect format. Look at the different values it takes with `unique()` and take the middle value. As an example, 1/5/00 should be 5. Number of open complaints is a string - remember you can use `split()` to deal with it and take the number you need. Finally, since it should be numeric, cast the column to be in its proper type.*

# %%
df_insurance
# Out:
#      customer   state gender             education customer_lifetime_value  \
# 0     RB50392      WA    NaN                Master                     NaN
# 1     QZ44356      AZ      F              Bachelor               697953.59
# 2     AI49188  Nevada      F              Bachelor              1288743.17
# 3     WW63253    Cali      M              Bachelor               764586.18
# 4     GA49547      WA      M  High School or Below               536307.65
# ...       ...     ...    ...                   ...                     ...
# 4003      NaN     NaN    NaN                   NaN                     NaN
# 4004      NaN     NaN    NaN                   NaN                     NaN
# 4005      NaN     NaN    NaN                   NaN                     NaN
# 4006      NaN     NaN    NaN                   NaN                     NaN
# 4007      NaN     NaN    NaN                   NaN                     NaN
#
# ...

# %%
df_insurance['customer_lifetime_value'] = df_insurance['customer_lifetime_value'].astype(float)

# %%
df_insurance.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
df_insurance["number_of_open_complaints"].unique()
# Out:
# array(['1/0/00', '1/2/00', '1/1/00', '1/3/00', '1/5/00', '1/4/00', nan],
#       dtype=object)

# %%
df_insurance["number_of_open_complaints"].value_counts()
# Out:
# number_of_open_complaints
# 1/0/00    830
# 1/1/00    138
# 1/2/00     50
# 1/3/00     34
# 1/4/00     13
# 1/5/00      6
# Name: count, dtype: int64

# %%
def extract_middle_value(complaints):
    if pd.isna(complaints):
        return None
    else:
        return complaints.split('/')[1]

df_insurance['number_of_open_complaints'] = df_insurance['number_of_open_complaints'].apply(extract_middle_value)  #.astype(float)

display(df_insurance)
# Out:
#      customer   state gender             education  customer_lifetime_value  \
# 0     RB50392      WA    NaN                Master                      NaN
# 1     QZ44356      AZ      F              Bachelor                697953.59
# 2     AI49188  Nevada      F              Bachelor               1288743.17
# 3     WW63253    Cali      M              Bachelor                764586.18
# 4     GA49547      WA      M  High School or Below                536307.65
# ...       ...     ...    ...                   ...                      ...
# 4003      NaN     NaN    NaN                   NaN                      NaN
# 4004      NaN     NaN    NaN                   NaN                      NaN
# 4005      NaN     NaN    NaN                   NaN                      NaN
# 4006      NaN     NaN    NaN                   NaN                      NaN
# 4007      NaN     NaN    NaN                   NaN                      NaN
#
# ...

# %%
df_insurance['number_of_open_complaints'] = df_insurance['number_of_open_complaints'].astype(float)

# %%
df_insurance['number_of_open_complaints'] = df_insurance['number_of_open_complaints'].astype(int, errors = "ignore")

# %%
df_insurance.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints    float64
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
display(df_insurance)
# Out:
#      customer   state gender             education  customer_lifetime_value  \
# 0     RB50392      WA    NaN                Master                      NaN
# 1     QZ44356      AZ      F              Bachelor                697953.59
# 2     AI49188  Nevada      F              Bachelor               1288743.17
# 3     WW63253    Cali      M              Bachelor                764586.18
# 4     GA49547      WA      M  High School or Below                536307.65
# ...       ...     ...    ...                   ...                      ...
# 4003      NaN     NaN    NaN                   NaN                      NaN
# 4004      NaN     NaN    NaN                   NaN                      NaN
# 4005      NaN     NaN    NaN                   NaN                      NaN
# 4006      NaN     NaN    NaN                   NaN                      NaN
# 4007      NaN     NaN    NaN                   NaN                      NaN
#
# ...

# %% [markdown]
# ## Exercise 4: Dealing with Null values

# %% [markdown]
# Identify any columns with null or missing values. Identify how many null values each column has. You can use the `isnull()` function in pandas to find columns with null values.
#
# Decide on a strategy for handling the null values. There are several options, including:
#
# - Drop the rows or columns with null values
# - Fill the null values with a specific value (such as the column mean or median for numerical variables, and mode for categorical variables)
# - Fill the null values with the previous or next value in the column
# - Fill the null values based on a more complex algorithm or model (note: we haven't covered this yet)
#
# Implement your chosen strategy to handle the null values. You can use the `fillna()` function in pandas to fill null values or `dropna()` function to drop null values.
#
# Verify that your strategy has successfully handled the null values. You can use the `isnull()` function again to check if there are still null values in the dataset.
#
# Remember to document your process and explain your reasoning for choosing a particular strategy for handling null values.
#
# After formatting data types, as a last step, convert all the numeric variables to integers.

# %%
df_insurance.isnull()
# Out:
#       customer  state  gender  education  customer_lifetime_value  income  \
# 0        False  False    True      False                     True   False
# 1        False  False   False      False                    False   False
# 2        False  False   False      False                    False   False
# 3        False  False   False      False                    False   False
# 4        False  False   False      False                    False   False
# ...        ...    ...     ...        ...                      ...     ...
# 4003      True   True    True       True                     True    True
# 4004      True   True    True       True                     True    True
# 4005      True   True    True       True                     True    True
# 4006      True   True    True       True                     True    True
# 4007      True   True    True       True                     True    True
#
#       monthly_premium_auto  number_of_open_complaints  policy_type  \
# ...

# %%
df_insurance.isnull().any() # checking for null values
# Out:
# customer                     True
# state                        True
# gender                       True
# education                    True
# customer_lifetime_value      True
# income                       True
# monthly_premium_auto         True
# number_of_open_complaints    True
# policy_type                  True
# vehicle_class                True
# total_claim_amount           True
# dtype: bool

# %%
df_insurance.isnull().sum() # many null values -> 2937 rows seems empty in every column
# Out:
# customer                     2937
# state                        3112
# gender                       3054
# education                    2937
# customer_lifetime_value      2940
# income                       2937
# monthly_premium_auto         2937
# number_of_open_complaints    2937
# policy_type                  2937
# vehicle_class                2937
# total_claim_amount           2937
# dtype: int64

# %%
#removing 2937 null vaules /overlapping in each column // removing them as a subset from customer an all the others should also be removed

df_insurance_null = df_insurance.dropna(how="all", subset =["customer", "education", "income", "monthly_premium_auto", "number_of_open_complaints", "policy_type", "vehicle_class", "total_claim_amount"])

df_insurance_null
# Out:
#      customer   state gender             education  customer_lifetime_value  \
# 0     RB50392      WA    NaN                Master                      NaN
# 1     QZ44356      AZ      F              Bachelor                697953.59
# 2     AI49188  Nevada      F              Bachelor               1288743.17
# 3     WW63253    Cali      M              Bachelor                764586.18
# 4     GA49547      WA      M  High School or Below                536307.65
# ...       ...     ...    ...                   ...                      ...
# 1066  TM65736  Oregon      M                Master                305955.03
# 1067  VJ51327     NaN      F  High School or Below               2031499.76
# 1068  GS98873      AZ      F              Bachelor                323912.47
# 1069  CW49887    Cali      F                Master                462680.11
# 1070  MY31220    Cali      F               College                899704.02
#
# ...

# %%
df_insurance_null.isnull().sum() #chek for changes
# Out:
# customer                       0
# state                        175
# gender                       117
# education                      0
# customer_lifetime_value        3
# income                         0
# monthly_premium_auto           0
# number_of_open_complaints      0
# policy_type                    0
# vehicle_class                  0
# total_claim_amount             0
# dtype: int64

# %%
df_insurance_null["state"].fillna("unknown", inplace = True) # replacing the null values with unknown
# Out:
# C:\Users\rk-admin\AppData\Local\Temp\ipykernel_5992\1882131308.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_insurance_null["state"].fillna("unknown", inplace = True) # replacing the null values with unknown
# C:\Users\rk-admin\AppData\Local\Temp\ipykernel_5992\1882131308.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_insurance_null["gender"].fillna("unknown", inplace = True) # replacing the null values with unknown
# Out:
# C:\Users\rk-admin\AppData\Local\Temp\ipykernel_5992\90110560.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_insurance_null["gender"].fillna("unknown", inplace = True) # replacing the null values with unknown
# C:\Users\rk-admin\AppData\Local\Temp\ipykernel_5992\90110560.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_insurance_null[df_insurance_null['customer_lifetime_value'].isnull()] #last null values
# Out:
#     customer state   gender             education  customer_lifetime_value  \
# 0    RB50392    WA  unknown                Master                      NaN
# 78   SP81997    WA        F                Master                      NaN
# 988  GT62080    WA        M  High School or Below                      NaN
#
#       income  monthly_premium_auto  number_of_open_complaints    policy_type  \
# 0        0.0                1000.0                        0.0  Personal Auto
# 78   41275.0                  96.0                        0.0  Personal Auto
# 988  55561.0                  63.0                        0.0  Personal Auto
#
#      vehicle_class  total_claim_amount
# 0    Four-Door Car            2.704934
# 78   Four-Door Car           41.122303
# 988  Four-Door Car          227.872071

# %%
mean_value = df_insurance_null[df_insurance_null['vehicle_class'] == 'Four-Door Car']['customer_lifetime_value'].mean() #calculating the mean of four door car (vehicle class)

mean_value
# Out:
# 669701.7526178011

# %%
df_insurance_null['customer_lifetime_value'] = df_insurance_null['customer_lifetime_value'].fillna(mean_value) #filling with the mean of four door car (vehicle class)
# Out:
# C:\Users\rk-admin\AppData\Local\Temp\ipykernel_5992\3247603421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_insurance_null['customer_lifetime_value'] = df_insurance_null['customer_lifetime_value'].fillna(mean_value) #filling with the mean of four door car (vehicle class)

# %%
df_insurance_null.isnull().sum() # no null values anymore
# Out:
# customer                     0
# state                        0
# gender                       0
# education                    0
# customer_lifetime_value      0
# income                       0
# monthly_premium_auto         0
# number_of_open_complaints    0
# policy_type                  0
# vehicle_class                0
# total_claim_amount           0
# dtype: int64

# %% [markdown]
# ## Exercise 5: Dealing with duplicates

# %% [markdown]
# Use the `.duplicated()` method to identify any duplicate rows in the dataframe.
#
# Decide on a strategy for handling the duplicates. Options include:
# - Dropping all duplicate rows
# - Keeping only the first occurrence of each duplicated row
# - Keeping only the last occurrence of each duplicated row
# - Dropping duplicates based on a subset of columns
# - Dropping duplicates based on a specific column
#
# Implement your chosen strategy using the `drop_duplicates()` function.
#
# Verify that your strategy has successfully handled the duplicates by checking for duplicates again using `.duplicated()`.
#
# Remember to document your process and explain your reasoning for choosing a particular strategy for handling duplicates.
#
# Save the cleaned dataset to a new CSV file.
#
# *Hint*: *after dropping duplicates, reset the index to ensure consistency*.

# %%
df_insurance.duplicated().sum() # checking for duplicates
# Out:
# 2936

# %%
df_insurance_duplicate_all = df_insurance.drop_duplicates() # deleting duplicates

df_insurance_duplicate_all
# Out:
#      customer   state gender             education  customer_lifetime_value  \
# 0     RB50392      WA    NaN                Master                      NaN
# 1     QZ44356      AZ      F              Bachelor                697953.59
# 2     AI49188  Nevada      F              Bachelor               1288743.17
# 3     WW63253    Cali      M              Bachelor                764586.18
# 4     GA49547      WA      M  High School or Below                536307.65
# ...       ...     ...    ...                   ...                      ...
# 1067  VJ51327     NaN      F  High School or Below               2031499.76
# 1068  GS98873      AZ      F              Bachelor                323912.47
# 1069  CW49887    Cali      F                Master                462680.11
# 1070  MY31220    Cali      F               College                899704.02
# 1071      NaN     NaN    NaN                   NaN                      NaN
#
# ...

# %%
df_first = df_insurance.drop_duplicates(keep='first') # does not really make sense tbh

df_last = df_insurance.drop_duplicates(keep='last') # does not really make sense tbh


df_insurance_new = pd.concat([df_first, df_last])


# doing this step, does not make sens at all in my opinion, i didi it for learning & tetsing

# %%
df_insurance_new
# Out:
#      customer   state gender             education  customer_lifetime_value  \
# 0     RB50392      WA    NaN                Master                      NaN
# 1     QZ44356      AZ      F              Bachelor                697953.59
# 2     AI49188  Nevada      F              Bachelor               1288743.17
# 3     WW63253    Cali      M              Bachelor                764586.18
# 4     GA49547      WA      M  High School or Below                536307.65
# ...       ...     ...    ...                   ...                      ...
# 1067  VJ51327     NaN      F  High School or Below               2031499.76
# 1068  GS98873      AZ      F              Bachelor                323912.47
# 1069  CW49887    Cali      F                Master                462680.11
# 1070  MY31220    Cali      F               College                899704.02
# 4007      NaN     NaN    NaN                   NaN                      NaN
#
# ...

# %%
df_insurance_new.duplicated().sum() # checking duplicates after merge
# Out:
# 1072

# %%
df_insurance_new.duplicated(subset=["customer"]).sum() # deleting duplicates after merge
# Out:
# 1072

# %%
df_insurance_duplicate = df_insurance_new.drop_duplicates(subset = ["customer"]) # save it in a new dataframe

df_insurance_duplicate
# Out:
#      customer   state gender             education  customer_lifetime_value  \
# 0     RB50392      WA    NaN                Master                      NaN
# 1     QZ44356      AZ      F              Bachelor                697953.59
# 2     AI49188  Nevada      F              Bachelor               1288743.17
# 3     WW63253    Cali      M              Bachelor                764586.18
# 4     GA49547      WA      M  High School or Below                536307.65
# ...       ...     ...    ...                   ...                      ...
# 1067  VJ51327     NaN      F  High School or Below               2031499.76
# 1068  GS98873      AZ      F              Bachelor                323912.47
# 1069  CW49887    Cali      F                Master                462680.11
# 1070  MY31220    Cali      F               College                899704.02
# 1071      NaN     NaN    NaN                   NaN                      NaN
#
# ...

# %%
df_insurance_duplicate.to_csv("lab.data.clean-and-form.csv")

# %% [markdown]
# # Bonus: Challenge 2: creating functions on a separate `py` file

# %% [markdown]
# Put all the data cleaning and formatting steps into functions, and create a main function that performs all the cleaning and formatting.
#
# Write these functions in separate .py file(s). By putting these steps into functions, we can make the code more modular and easier to maintain.

# %% [markdown]
# *Hint: autoreload module is a utility module in Python that allows you to automatically reload modules in the current session when changes are made to the source code. This can be useful in situations where you are actively developing code and want to see the effects of changes you make without having to constantly restart the Python interpreter or Jupyter Notebook kernel.*

# %%
# Your code here

# %% [markdown]
# # Bonus: Challenge 3: Analyzing Clean and Formated Data

# %% [markdown]
# You have been tasked with analyzing the data to identify potential areas for improving customer retention and profitability. Your goal is to identify customers with a high policy claim amount and a low customer lifetime value.
#
# In the Pandas Lab, we only looked at high policy claim amounts because we couldn't look into low customer lifetime values. If we had tried to work with that column, we wouldn't have been able to because customer lifetime value wasn't clean and in its proper format. So after cleaning and formatting the data, let's get some more interesting insights!
#
# Instructions:
#
# - Review the statistics again for total claim amount and customer lifetime value to gain an understanding of the data.
# - To identify potential areas for improving customer retention and profitability, we want to focus on customers with a high policy claim amount and a low customer lifetime value. Consider customers with a high policy claim amount to be those in the top 25% of the total claim amount, and clients with a low customer lifetime value to be those in the bottom 25% of the customer lifetime value. Create a pandas DataFrame object that contains information about customers with a policy claim amount greater than the 75th percentile and a customer lifetime value in the bottom 25th percentile.
# - Use DataFrame methods to calculate summary statistics about the high policy claim amount and low customer lifetime value data. To do so, select both columns of the dataframe simultaneously and pass it to the `.describe()` method. This will give you descriptive statistics, such as mean, median, standard deviation, minimum and maximum values for both columns at the same time, allowing you to compare and analyze their characteristics.

# %%
# Your code here
